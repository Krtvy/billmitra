# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
#setup hai pehle aur matplotlib.pyplot is standard hai

# %%
df=read_csv('locationofthefile/filename.csv)
#df is dataframe aur read_csv pandas ka function hai jo comma seperated variable read krta hai
#display be krenge jo kiya hai abhit

print("Data loaded Successfully")
print(f"The total rows:{lef(df)}")
print(f"The total column{lef(df.columns)}")


#this is the calculate the count of rows and columns but there are alternatives too for row df.shape[0] for columns df.shape[1] 
#also df.info() se bhi ho jata hai to bhatere variations hai
# Out:
#   Cell In[10], line 1
#     df=read_csv('locationofthefile/filename.csv)
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("First five rows of data")
print(df.head())

print("Column name")
print(df.columns.tolist())

print("Data Types")
print(df.dtypes())
# Out:
# First five rows of data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 print("First five rows of data")
# ----> 2 print(df.head())
#       4 print("Column name")
#       5 print(df.columns.tolist())
#
# NameError: name 'df' is not defined

# %%
print("Summary Statistics")
print(df.describe())
# Out:
# Summary Statistics
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 print("Summary Statistics")
# ----> 2 print(df.describe())
#
# NameError: name 'df' is not defined

# %%
print("Missing Value per column")
print(df.isnull().sum())
# Out:
# Missing Value per column
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 print("Missing Value per column")
# ----> 2 print(df.isnull().sum())
#
# NameError: name 'df' is not defined

# %%
print(df.isnull().sum(())
# Out:
#   Cell In[14], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
print(df.isnull().sum(())
# Out:
#   Cell In[15], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
duplicates=df.duplicates().sum()
print(f"The number of duplicated:{duplicated}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 duplicates=df.duplicates().sum()
#       2 print(f"The number of duplicated:{duplicated}")
#
# NameError: name 'df' is not defined

# %%
if df['Date'].dtype=='object':
 df['Date']=pd.to_dateime(['Date'])
# Out:
#   Cell In[17], line 1
#     if df['Date'].dtype=='object'
#                                  ^
# SyntaxError: expected ':'

# %%
daily_total=df.grouby('Date')['QuantitySold'].sum()
plt.fig(figsize(12,9))
plt.plot(daily_total.index,daily_total.values,linewidth=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 daily_total=df.grouby('Date')['QuantitySold'].sum()
#
# NameError: name 'df' is not defined
